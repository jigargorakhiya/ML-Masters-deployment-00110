# %% [markdown]
# Q1: a) Bypassing the given list to the iter() function<br/>
# Q2: b) a generator function<br/>
# Q3: b)19 <br/>
# Q4: d) All of the above. <br/>
# Q5: d) 50 <br/>
# Q6: c)  I got decorated I am ordinary<br/>
# Q7: a) Decorators <br/>
# Q8: a)   getter() and setter()<br/>
# Q9: c) The @ symbol doesn’t have any use while using decorators<br/>
# Q10	a)  Print Hello() is a function, and a is a variable. None of them are objects.
# Q11: c)  a = 20<br/>
# Q12: a)  A class is a blueprint for the object.<br/>
# Q13: c) Java<br/>
# Q14: b)  This function is called, when the new object is instantiated<br/>
# Q15: b)  1 1<br/>
# Q16: c)<br/>
# Q17: a) Multiple Inheritance<br/>
# Q18: a) All of the above.<br/>
# Q19:  b)  4 6<br/>
# Q20:  c) opens the file for appending, at the end of file<br/>
# Q21: a)  Opens test.txt file for reading only<br/>
# Q22: a) with open("test.txt", encoding = 'utf-8')  as  f:<br/>
# Q23: d)<br/>
# Q24:  c) Prints all the directories and files inside the given directory<br/>
# Q25: a) An exception is an error that occurs in the runtime.<br/>
# Q26: c)  An exception is raised.<br/>
# Q27:  b) 2.0<br/>
# Q28:  c) Prints Two if the TypeError or ZeroDivisionError exception occurs.<br/>
# Q29: b)  You can create the user-defined exception by deriving a class from Exception class.<br/>
# Q30:  c) The function is a piece of code that can perform a specific task.<br/>
# Q31: b) Python is awesome.<br/>
# Q32:  b) None object<br/>
# Q33:  b) Hello ('Frodo', 'Sauron')<br/>
# Q34:  b) A function that calls itself.<br/>
# Q35: c) 25<br/>
# Q36:  a) 10<br/>
# Q37: "c) 1.	 from math import pi 2.	 print(pi)"
# Q38:  a). operator<br/>
# Q39:  b) (1, 3, 6)<br/>
# Q40:  c) Nothing will be printed<br/>
# Q41: a)True.<br/>
# Q42:  a) 2
#          1 <br/>
# Q43:  a) Only for loop can have the optional else statement<br/>
# Q44: b) 10<br/>
# Q45:  c)   4 is printed infinitely until the program closes<br/>
# Q46:  b) Yes, for loop is more pythonic choice.<br/>
# Q47:  d) All of the above.<br/>
# Q48:  b) PYTHONSTRING<br/>
# Q49: a)  It is used as the placeholder for future implementation of functions, loops, etc<br/>
# Q50: a)  Any character such as the comma (,) or tab (\t ) that is used to separate  the column data.<br/>
# Q51:  a) The column names of the data.<br/>
# Q52:  b)   csv.reader(my_data, delimiter='\t')<br/>
# Q53:  b) The row data as a list<br/>
# Q54:  c) Each key must match up to the field names (column names) used to identify the column data<br/>
# Q55: c) pandas.read_csv('hrdata.csv')<br/>
# Q56: a) pandas.read_csv('hrdata.csv', index_col='Name') <br/>
# Q57: "b)	open('dog_breeds.txt', 'r')
#         c)	open('dog_breeds.txt')"<br/>
# Q58: "import os
#         cwd = os.getcwd() + ""/feeline/"""<br/>
# Q59: open('jack_russell.png', 'rb')<br/>
# Q60: "import os
#         cwd = os.getcwd() + “/ursine/bears.gif"<br/>
# Q61: a) Making sure that you use the .close() method before the end of the script<br/>
# Q62: "animals/ursine/bears.gif"<br/>
# Q63:  b) .read()<br/>
# Q64:  b) 1.7<br/>
# Q65:  a) -2.96<br/>
# Q66:  a) Positive numbers are rounded up, and negative numbers are rounded down.<br/>
# Q67:  b)   -0.04<br/>
# Q68:  d) Round half to even<br/>
# Q69:  a)   4.6<br/>
# Q70: a) Diamond<br/>
# Q71: "c)	At least 3 "<br/>
# Q72: a) Class a. <br/>
# Q73: "c)	Derived class can still access them in the multiple inheritance "<br/>
# Q74: d) No, since constructors won’t be there<br/>
# Q75: d) Class which have more than one parent<br/>
# Q76: "c)	C"<br/>
# Q77: "c)	Class at 5th level"<br/>
# Q78: d) As many levels of inheritance as required<br/>
# Q79: "b)	Object of lower-level classes must call parent class constructors explicitly"<br/>
# Q80: d) Exceptions<br/>
# Q81: "c)	Runtime exceptions and other exceptions "<br/>
# Q82: "a)	Try and catch"<br/>
# Q83: a) An object must be created to catch the exception <br/>
# Q84: c) IOExceptions <br/>
# Q85: "d)	Both base class and derived class may produce exceptions"<br/>
# Q86: a) Then catch block of a derived class must be defined before the base class <br/>
# Q87: "b)	Before derived class is not allowed by the compiler "<br/>
# Q88: d) ClassNotFoundException<br/>
# Q89: "c)	Both the base and derived class catch the blocks are important."<br/>
# Q90: c) Infinite Loops<br/>
# Q91: "b) 	Functions made to maintain a single copy of member functions for all the objects "<br/>
# Q92: c) Having access to only the static members of a class<br/>
# Q93: d) className :: functionName;<br/>
# Q94: d) Created and initialised, only once<br/>
# Q95: b) Static member functions can’t be overloaded.<br/>
# Q96: d) Can’t be declared const, volatile, or constant volatile.<br/>
# Q97: c) Single colon.<br/>
# Q98: c) Those can be initialised within the class.<br/>
# Q99: b) Can’t be mutable.<br/>
# Q100: a) Even if a class object is not created<br/>
# Q101: c) rPy provides lots of scientific routines that work on top of NumPy.<br/>
# Q102: a) reshape, resize.<br/>
# Q103: a) arrange.<br/>
# Q104:  d) All of the mentioned<br/>
# Q105: b) Column_stack<br/>
# Q106: a) True<br/>
# Q107: b) copy.<br/>
# Q108: b) ix_.<br/>
# Q109: a) True<br/>
# Q110: d) all of the Mentioned<br/>
# Q111: c) setbufsize(size) <br/>
# Q112: b) In Numpy, universal functions are the instances of numpy.ufunction class <br/>
# Q113: a) .types<br/>
# Q114: b) ones_like<br/>
# Q115: c) The output of the ufunc is necessarily a ndarray, if all the input arguments are ndarrays<br/>
# Q116: b) settercall.<br/>
# Q117: b) False<br/>
# Q118: c) frexp<br/>
# Q119: a) iscomplex.<br/>
# Q120: a) True<br/>
# Q121: c) value,size.<br/>
# Q122: d) All of the above mentioned.<br/>
# Q123: a) import pandas as pd<br/>
# Q124: a) DataFrame.<br/>
# Q125: c) The panel is generally 2D labelled, also a size-mutable array.<br/>
# Q126: a) numpy.<br/>
# Q127: b) False<br/>
# Q128: c) Statsmodels. <br/>
# Q129: a) yhat.<br/>
# Q130: a) True<br/>
# Q131: a) Quandl.<br/>
# Q132: a) Statsmodels provides powerful statistics, econometrics, analysis and the modelling functionality which is out of pandas’ scope<br/>
# Q133: a) pandaSDMX <br/>
# Q134: a) Blaze. <br/>
# Q135: c) Spyder is a cross-platform Qt-based open-source R ID<br/>
# Q136: b) freedapi.<br/>
# Q137: b) False<br/>
# Q138: a) sci-kit-learn.<br/>
# Q139: b) Seaborn. <br/>
# Q140: a) True<br/>
# Q141: b) SparseArray.<br/>
# Q142: d) All of the mentioned.<br/>
# Q143: d) None of the mentioned.<br/>
# Q144: a) SparseList.<br/>
# Q145: a) to_array. append can accept scalar values or any 2-D sequence.<br/>
# Q146: a) SparseSeries.to_coo(). <br/>
# Q147: b) False <br/>
# Q148: a) in.<br/>
# Q149: b) ix. <br/>
# Q150: a) True <br/>
